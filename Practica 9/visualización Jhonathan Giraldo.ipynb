# %% [markdown]
# # Taller NPL Visualización
# ## Nube de palabras  Jhonathan Giraldo

# %%
import numpy as np
 
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
 
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
 
import matplotlib.pyplot as plt
import PIL.Image

from IPython.display import display

# %%
#Carga de la imagen
dragonball = PIL.Image.open("kdb.jpg")
display(dragonball)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x600 at 0x1564E923F88>

# %%
mask = np.array(dragonball)
mask
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#Cargar el texto
import pandas as pd
data = pd.read_csv('characters_list.csv')
data.head()
# Out:
#            Name                                        description  \
# 0           Abo  A member of Freeza's Planet Trade Organization...
# 1          Abra  A Neko Majin owned by the human turned majin K...
# 2           Ace  The hero of Tokitoki City and an excellent Tim...
# 3        Ackman  A demon who kills people to steal their soul t...
# 4  Adolf Hitler  The man who ruled over Nazi Germany during Wor...
#
#                                             imageUrl
# 0  https://static.comicvine.com/uploads/square_sm...
# 1  https://static.comicvine.com/uploads/square_sm...
# 2  https://static.comicvine.com/uploads/square_sm...
# 3  https://static.comicvine.com/uploads/square_sm...
# 4  https://static.comicvine.com/uploads/square_sm...

# %%
palabras = data.description.str.cat(sep=" ")
wordcloud = WordCloud().generate(palabras)
 
plt.imshow(wordcloud)
plt.show()

# %%
palabras = data.description.str.cat(sep=' ')
 
wordcloud = WordCloud(width=800, height=400,
                      max_font_size=150, max_words=250,
                      background_color='black', colormap='cool',
                      #stopwords=stopwords,
                      mask=mask, contour_width=0.5, contour_color='skyblue').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
 
wordcloud.to_file("kdb.png")
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
